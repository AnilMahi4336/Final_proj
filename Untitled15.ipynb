# %% [markdown]
# <a href="https://colab.research.google.com/github/AnilMahi4336/Final_proj/blob/master/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AnilMahi4336/Final_proj
# Out:
# Cloning into 'Final_proj'...
# remote: Enumerating objects: 1439, done.
# remote: Counting objects: 100% (1439/1439), done.
# remote: Compressing objects: 100% (1428/1428), done.
# remote: Total 1439 (delta 10), reused 1439 (delta 10), pack-reused 0
# Receiving objects: 100% (1439/1439), 574.83 MiB | 39.90 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# Checking out files: 100% (1419/1419), done.

# %%
# !python train.py --model Model --num_epochs 160
# Out:
# 2019-05-12 04:33:26.114306: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-05-12 04:33:26.114523: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2807440 executing computations on platform Host. Devices:
# 2019-05-12 04:33:26.114556: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-05-12 04:33:26.294458: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-05-12 04:33:26.294999: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2807180 executing computations on platform CUDA. Devices:
# 2019-05-12 04:33:26.295030: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2019-05-12 04:33:26.295385: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:00:04.0
# totalMemory: 14.73GiB freeMemory: 14.60GiB
# 2019-05-12 04:33:26.295410: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-05-12 04:33:26.780334: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-05-12 04:33:26.780394: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-05-12 04:33:26.780409: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-05-12 04:33:26.780762: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14115 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
# Preparing the model ...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /content/Final_proj/models/Model.py:259: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /content/Final_proj/models/Model.py:173: average_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.average_pooling2d instead.
# WARNING:tensorflow:From train.py:144: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# This model has 48717134 trainable parameters
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Loading the data ...
#
# ***** Begin training *****
# Dataset --> CamVid
# Model --> Model
# Crop Height --> 512
# Crop Width --> 512
# Num Epochs --> 160
# Batch Size --> 1
# Num Classes --> 32
# [2019-05-12 04:34:11] Epoch = 0 Count = 20 Current_Loss = 3.6875 Time = 25.57
# [2019-05-12 04:34:22] Epoch = 0 Count = 40 Current_Loss = 3.7630 Time = 11.51
# [2019-05-12 04:34:34] Epoch = 0 Count = 60 Current_Loss = 3.0795 Time = 11.59
# [2019-05-12 04:34:45] Epoch = 0 Count = 80 Current_Loss = 3.7228 Time = 11.63
# [2019-05-12 04:34:57] Epoch = 0 Count = 100 Current_Loss = 2.9990 Time = 11.67
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 04:35:09] Epoch = 0 Count = 120 Current_Loss = 2.9977 Time = 11.88
# [2019-05-12 04:35:21] Epoch = 0 Count = 140 Current_Loss = 2.8025 Time = 11.65
# [2019-05-12 04:35:32] Epoch = 0 Count = 160 Current_Loss = 2.8692 Time = 11.49
# [2019-05-12 04:35:44] Epoch = 0 Count = 180 Current_Loss = 2.9405 Time = 11.52
# [2019-05-12 04:35:55] Epoch = 0 Count = 200 Current_Loss = 2.6158 Time = 11.53
# [2019-05-12 04:36:07] Epoch = 0 Count = 220 Current_Loss = 2.8793 Time = 11.58
# [2019-05-12 04:36:19] Epoch = 0 Count = 240 Current_Loss = 2.7488 Time = 11.81
# [2019-05-12 04:36:30] Epoch = 0 Count = 260 Current_Loss = 2.4973 Time = 11.85
# [2019-05-12 04:36:42] Epoch = 0 Count = 280 Current_Loss = 2.6615 Time = 11.56
# [2019-05-12 04:36:54] Epoch = 0 Count = 300 Current_Loss = 2.8961 Time = 11.61
# [2019-05-12 04:37:05] Epoch = 0 Count = 320 Current_Loss = 2.5994 Time = 11.50
# [2019-05-12 04:37:17] Epoch = 0 Count = 340 Current_Loss = 2.5123 Time = 11.50
# [2019-05-12 04:37:28] Epoch = 0 Count = 360 Current_Loss = 2.2599 Time = 11.58
# [2019-05-12 04:37:40] Epoch = 0 Count = 380 Current_Loss = 2.2340 Time = 11.58
# [2019-05-12 04:37:52] Epoch = 0 Count = 400 Current_Loss = 2.4826 Time = 11.94
# [2019-05-12 04:38:03] Epoch = 0 Count = 420 Current_Loss = 2.5565 Time = 11.57
# Saving latest checkpoint
# Saving checkpoint for this epoch
# Performing validation
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1145: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1143: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/classification.py:1145: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
#
# Average validation accuracy for epoch # 0000 = 0.324283
# Average per class validation accuracies for epoch # 0000:
# Animal = 0.950000
# Archway = 0.900000
# Bicyclist = 0.550000
# Bridge = 0.950812
# Building = 0.135589
# Car = 0.309662
# CartLuggagePram = 0.750000
# Child = 0.950000
# Column_Pole = 0.104100
# Fence = 0.724150
# LaneMkgsDriv = 0.106904
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.534120
# MotorcycleScooter = 0.950000
# OtherMoving = 0.700245
# ParkingBlock = 0.758906
# Pedestrian = 0.300026
# Road = 0.843314
# RoadShoulder = 0.950063
# Sidewalk = 0.131872
# SignSymbol = 0.350000
# Sky = 0.902670
# SUVPickupTruck = 0.650000
# TrafficCone = 1.000000
# TrafficLight = 0.450000
# Train = 1.000000
# Tree = 0.190564
# Truck_Bus = 0.800732
# Tunnel = 1.000000
# VegetationMisc = 0.701455
# Void = 0.004649
# Wall = 0.361299
# Validation precision =  0.453824340221745
# Validation recall =  0.32428340911865233
# Validation F1 score =  0.3241077946044924
# Validation IoU score =  0.09383307597271315
# [2019-05-12 04:38:30] Remaining training time = 12 hours 34 minutes 15 seconds
#
# [2019-05-12 04:38:42] Epoch = 1 Count = 20 Current_Loss = 2.4297 Time = 11.71
# [2019-05-12 04:38:54] Epoch = 1 Count = 40 Current_Loss = 2.2278 Time = 11.76
# [2019-05-12 04:39:06] Epoch = 1 Count = 60 Current_Loss = 2.5751 Time = 11.78
# [2019-05-12 04:39:18] Epoch = 1 Count = 80 Current_Loss = 2.4752 Time = 11.88
# [2019-05-12 04:39:29] Epoch = 1 Count = 100 Current_Loss = 2.0846 Time = 11.53
# [2019-05-12 04:39:41] Epoch = 1 Count = 120 Current_Loss = 2.2059 Time = 11.47
# [2019-05-12 04:39:52] Epoch = 1 Count = 140 Current_Loss = 2.2248 Time = 11.51
# [2019-05-12 04:40:04] Epoch = 1 Count = 160 Current_Loss = 2.0547 Time = 11.52
# [2019-05-12 04:40:15] Epoch = 1 Count = 180 Current_Loss = 2.0935 Time = 11.62
# [2019-05-12 04:40:27] Epoch = 1 Count = 200 Current_Loss = 2.3335 Time = 11.76
# [2019-05-12 04:40:39] Epoch = 1 Count = 220 Current_Loss = 1.9436 Time = 11.86
# [2019-05-12 04:40:50] Epoch = 1 Count = 240 Current_Loss = 2.3227 Time = 11.53
# [2019-05-12 04:41:02] Epoch = 1 Count = 260 Current_Loss = 1.7870 Time = 11.51
# [2019-05-12 04:41:13] Epoch = 1 Count = 280 Current_Loss = 2.0298 Time = 11.49
# [2019-05-12 04:41:25] Epoch = 1 Count = 300 Current_Loss = 1.9424 Time = 11.76
# [2019-05-12 04:41:37] Epoch = 1 Count = 320 Current_Loss = 2.1233 Time = 11.54
# [2019-05-12 04:41:49] Epoch = 1 Count = 340 Current_Loss = 3.0159 Time = 11.78
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 04:42:00] Epoch = 1 Count = 360 Current_Loss = 2.0613 Time = 11.79
# [2019-05-12 04:42:12] Epoch = 1 Count = 380 Current_Loss = 2.1582 Time = 11.52
# [2019-05-12 04:42:23] Epoch = 1 Count = 400 Current_Loss = 1.8309 Time = 11.55
# [2019-05-12 04:42:35] Epoch = 1 Count = 420 Current_Loss = 1.8468 Time = 11.45
# Saving latest checkpoint
# Performing validation
#
# Average validation accuracy for epoch # 0001 = 0.429077
# Average per class validation accuracies for epoch # 0001:
# Animal = 0.950000
# Archway = 0.900000
# Bicyclist = 0.550000
# Bridge = 0.951959
# Building = 0.378150
# Car = 0.435063
# CartLuggagePram = 0.750000
# Child = 0.950000
# Column_Pole = 0.103110
# Fence = 0.719137
# LaneMkgsDriv = 0.101291
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.399437
# MotorcycleScooter = 0.950000
# OtherMoving = 0.702240
# ParkingBlock = 0.758697
# Pedestrian = 0.300172
# Road = 0.891057
# RoadShoulder = 0.950000
# Sidewalk = 0.075443
# SignSymbol = 0.350346
# Sky = 0.925546
# SUVPickupTruck = 0.650000
# TrafficCone = 1.000000
# TrafficLight = 0.450000
# Train = 1.000000
# Tree = 0.305495
# Truck_Bus = 0.800732
# Tunnel = 1.000000
# VegetationMisc = 0.796377
# Void = 0.013033
# Wall = 0.355888
# Validation precision =  0.5054152452063818
# Validation recall =  0.4290769577026367
# Validation F1 score =  0.4092528050076313
# Validation IoU score =  0.11826601064534878
# [2019-05-12 04:42:54] Remaining training time = 11 hours 33 minutes 57 seconds
#
# [2019-05-12 04:43:06] Epoch = 2 Count = 20 Current_Loss = 2.1346 Time = 11.61
# [2019-05-12 04:43:18] Epoch = 2 Count = 40 Current_Loss = 1.7756 Time = 11.87
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 04:43:30] Epoch = 2 Count = 60 Current_Loss = 2.2046 Time = 12.07
# [2019-05-12 04:43:42] Epoch = 2 Count = 80 Current_Loss = 1.8049 Time = 11.36
# [2019-05-12 04:43:53] Epoch = 2 Count = 100 Current_Loss = 1.8745 Time = 11.28
# [2019-05-12 04:44:04] Epoch = 2 Count = 120 Current_Loss = 1.7686 Time = 11.30
# [2019-05-12 04:44:15] Epoch = 2 Count = 140 Current_Loss = 1.8498 Time = 11.30
# [2019-05-12 04:44:27] Epoch = 2 Count = 160 Current_Loss = 2.0830 Time = 11.49
# [2019-05-12 04:44:39] Epoch = 2 Count = 180 Current_Loss = 1.4652 Time = 11.85
# [2019-05-12 04:44:50] Epoch = 2 Count = 200 Current_Loss = 1.3712 Time = 11.35
# [2019-05-12 04:45:01] Epoch = 2 Count = 220 Current_Loss = 2.1962 Time = 11.31
# [2019-05-12 04:45:13] Epoch = 2 Count = 240 Current_Loss = 1.7377 Time = 11.29
# [2019-05-12 04:45:24] Epoch = 2 Count = 260 Current_Loss = 1.7261 Time = 11.31
# [2019-05-12 04:45:35] Epoch = 2 Count = 280 Current_Loss = 2.1612 Time = 11.33
# [2019-05-12 04:45:47] Epoch = 2 Count = 300 Current_Loss = 2.0848 Time = 11.42
# [2019-05-12 04:45:59] Epoch = 2 Count = 320 Current_Loss = 1.6701 Time = 11.82
# [2019-05-12 04:46:10] Epoch = 2 Count = 340 Current_Loss = 1.6204 Time = 11.33
# [2019-05-12 04:46:21] Epoch = 2 Count = 360 Current_Loss = 1.8643 Time = 11.33
# [2019-05-12 04:46:33] Epoch = 2 Count = 380 Current_Loss = 1.5952 Time = 11.66
# [2019-05-12 04:46:44] Epoch = 2 Count = 400 Current_Loss = 1.4154 Time = 11.33
# [2019-05-12 04:46:56] Epoch = 2 Count = 420 Current_Loss = 1.5463 Time = 11.35
# Saving latest checkpoint
# Performing validation
#
# Average validation accuracy for epoch # 0002 = 0.540702
# Average per class validation accuracies for epoch # 0002:
# Animal = 0.950000
# Archway = 0.900000
# Bicyclist = 0.550359
# Bridge = 0.952864
# Building = 0.615191
# Car = 0.589205
# CartLuggagePram = 0.750000
# Child = 0.950000
# Column_Pole = 0.100743
# Fence = 0.714037
# LaneMkgsDriv = 0.102495
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.274230
# MotorcycleScooter = 0.950000
# OtherMoving = 0.700234
# ParkingBlock = 0.750000
# Pedestrian = 0.300000
# Road = 0.909836
# RoadShoulder = 0.950000
# Sidewalk = 0.062490
# SignSymbol = 0.350000
# Sky = 0.949975
# SUVPickupTruck = 0.650252
# TrafficCone = 1.000000
# TrafficLight = 0.450000
# Train = 1.000000
# Tree = 0.605374
# Truck_Bus = 0.800000
# Tunnel = 1.000000
# VegetationMisc = 0.827414
# Void = 0.005671
# Wall = 0.354369
# Validation precision =  0.6497675495557582
# Validation recall =  0.5407016754150391
# Validation F1 score =  0.5333507361185138
# Validation IoU score =  0.1439376682562339
# [2019-05-12 04:47:16] Remaining training time = 11 hours 23 minutes 7 seconds
#
# [2019-05-12 04:47:28] Epoch = 3 Count = 20 Current_Loss = 1.3726 Time = 11.34
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 04:47:39] Epoch = 3 Count = 40 Current_Loss = 1.4672 Time = 11.42
# [2019-05-12 04:47:51] Epoch = 3 Count = 60 Current_Loss = 1.1660 Time = 11.39
# [2019-05-12 04:48:02] Epoch = 3 Count = 80 Current_Loss = 1.3289 Time = 11.31
# [2019-05-12 04:48:13] Epoch = 3 Count = 100 Current_Loss = 1.5014 Time = 11.29
# [2019-05-12 04:48:24] Epoch = 3 Count = 120 Current_Loss = 1.3017 Time = 11.29
# [2019-05-12 04:48:36] Epoch = 3 Count = 140 Current_Loss = 1.7762 Time = 11.96
# [2019-05-12 04:48:48] Epoch = 3 Count = 160 Current_Loss = 1.6508 Time = 11.55
# [2019-05-12 04:48:59] Epoch = 3 Count = 180 Current_Loss = 1.4650 Time = 11.34
# [2019-05-12 04:49:11] Epoch = 3 Count = 200 Current_Loss = 1.2443 Time = 11.33
# [2019-05-12 04:49:22] Epoch = 3 Count = 220 Current_Loss = 1.2593 Time = 11.34
# [2019-05-12 04:49:33] Epoch = 3 Count = 240 Current_Loss = 1.9985 Time = 11.31
# [2019-05-12 04:49:45] Epoch = 3 Count = 260 Current_Loss = 1.2773 Time = 11.33
# [2019-05-12 04:49:57] Epoch = 3 Count = 280 Current_Loss = 1.8218 Time = 11.91
# [2019-05-12 04:50:08] Epoch = 3 Count = 300 Current_Loss = 0.9758 Time = 11.37
# [2019-05-12 04:50:19] Epoch = 3 Count = 320 Current_Loss = 1.0901 Time = 11.32
# [2019-05-12 04:50:31] Epoch = 3 Count = 340 Current_Loss = 0.9958 Time = 11.30
# [2019-05-12 04:50:42] Epoch = 3 Count = 360 Current_Loss = 1.3677 Time = 11.32
# [2019-05-12 04:50:53] Epoch = 3 Count = 380 Current_Loss = 1.2544 Time = 11.32
# [2019-05-12 04:51:04] Epoch = 3 Count = 400 Current_Loss = 1.1374 Time = 11.32
# [2019-05-12 04:51:16] Epoch = 3 Count = 420 Current_Loss = 1.2608 Time = 11.92
# Saving latest checkpoint
# Performing validation
#
# Average validation accuracy for epoch # 0003 = 0.600241
# Average per class validation accuracies for epoch # 0003:
# Animal = 0.950000
# Archway = 0.900000
# Bicyclist = 0.551218
# Bridge = 0.950000
# Building = 0.716435
# Car = 0.760900
# CartLuggagePram = 0.750000
# Child = 0.950000
# Column_Pole = 0.102341
# Fence = 0.700000
# LaneMkgsDriv = 0.100000
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.266392
# MotorcycleScooter = 0.950000
# OtherMoving = 0.700245
# ParkingBlock = 0.750000
# Pedestrian = 0.300769
# Road = 0.946311
# RoadShoulder = 0.950000
# Sidewalk = 0.188307
# SignSymbol = 0.350000
# Sky = 0.962249
# SUVPickupTruck = 0.658320
# TrafficCone = 1.000000
# TrafficLight = 0.450000
# Train = 1.000000
# Tree = 0.703354
# Truck_Bus = 0.800000
# Tunnel = 1.000000
# VegetationMisc = 0.758530
# Void = 0.026185
# Wall = 0.359030
# Validation precision =  0.7472326244206868
# Validation recall =  0.6002405166625977
# Validation F1 score =  0.6052711482907533
# Validation IoU score =  0.16539697215977442
# [2019-05-12 04:51:36] Remaining training time = 11 hours 14 minutes 56 seconds
#
# [2019-05-12 04:51:48] Epoch = 4 Count = 20 Current_Loss = 1.3089 Time = 11.44
# [2019-05-12 04:52:00] Epoch = 4 Count = 40 Current_Loss = 1.3804 Time = 11.39
# [2019-05-12 04:52:11] Epoch = 4 Count = 60 Current_Loss = 1.0500 Time = 11.40
# [2019-05-12 04:52:22] Epoch = 4 Count = 80 Current_Loss = 1.5272 Time = 11.36
# [2019-05-12 04:52:34] Epoch = 4 Count = 100 Current_Loss = 1.1037 Time = 11.72
# [2019-05-12 04:52:46] Epoch = 4 Count = 120 Current_Loss = 0.8946 Time = 11.53
# [2019-05-12 04:52:57] Epoch = 4 Count = 140 Current_Loss = 0.9150 Time = 11.30
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 04:53:08] Epoch = 4 Count = 160 Current_Loss = 1.2062 Time = 11.35
# [2019-05-12 04:53:20] Epoch = 4 Count = 180 Current_Loss = 0.8562 Time = 11.35
# [2019-05-12 04:53:31] Epoch = 4 Count = 200 Current_Loss = 1.3937 Time = 11.37
# [2019-05-12 04:53:42] Epoch = 4 Count = 220 Current_Loss = 1.0410 Time = 11.54
# [2019-05-12 04:53:55] Epoch = 4 Count = 240 Current_Loss = 1.1851 Time = 12.11
# [2019-05-12 04:54:06] Epoch = 4 Count = 260 Current_Loss = 0.6883 Time = 11.64
# [2019-05-12 04:54:18] Epoch = 4 Count = 280 Current_Loss = 1.1447 Time = 11.38
# [2019-05-12 04:54:29] Epoch = 4 Count = 300 Current_Loss = 1.8398 Time = 11.48
# [2019-05-12 04:54:41] Epoch = 4 Count = 320 Current_Loss = 1.0323 Time = 11.43
# [2019-05-12 04:54:52] Epoch = 4 Count = 340 Current_Loss = 1.0922 Time = 11.34
# [2019-05-12 04:55:03] Epoch = 4 Count = 360 Current_Loss = 1.4119 Time = 11.37
# [2019-05-12 04:55:15] Epoch = 4 Count = 380 Current_Loss = 1.0711 Time = 11.71
# [2019-05-12 04:55:27] Epoch = 4 Count = 400 Current_Loss = 1.0220 Time = 11.58
# [2019-05-12 04:55:38] Epoch = 4 Count = 420 Current_Loss = 1.1052 Time = 11.34
# Saving latest checkpoint
# Performing validation
#
# Average validation accuracy for epoch # 0004 = 0.645660
# Average per class validation accuracies for epoch # 0004:
# Animal = 0.950000
# Archway = 0.900000
# Bicyclist = 0.559210
# Bridge = 0.950000
# Building = 0.735698
# Car = 0.857314
# CartLuggagePram = 0.750000
# Child = 0.950000
# Column_Pole = 0.101787
# Fence = 0.700539
# LaneMkgsDriv = 0.102422
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.278679
# MotorcycleScooter = 0.950000
# OtherMoving = 0.700000
# ParkingBlock = 0.750000
# Pedestrian = 0.339886
# Road = 0.976014
# RoadShoulder = 0.950000
# Sidewalk = 0.314220
# SignSymbol = 0.350000
# Sky = 0.939749
# SUVPickupTruck = 0.709099
# TrafficCone = 1.000000
# TrafficLight = 0.457582
# Train = 1.000000
# Tree = 0.818671
# Truck_Bus = 0.800000
# Tunnel = 1.000000
# VegetationMisc = 0.740107
# Void = 0.068476
# Wall = 0.401258
# Validation precision =  0.7804142036308678
# Validation recall =  0.6456602096557618
# Validation F1 score =  0.644190985327757
# Validation IoU score =  0.20040515013673535
# [2019-05-12 04:55:57] Remaining training time = 11 hours 12 minutes 24 seconds
#
# [2019-05-12 04:56:09] Epoch = 5 Count = 20 Current_Loss = 0.7807 Time = 11.37
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 04:56:20] Epoch = 5 Count = 40 Current_Loss = 0.8064 Time = 11.41
# [2019-05-12 04:56:32] Epoch = 5 Count = 60 Current_Loss = 1.5794 Time = 11.56
# [2019-05-12 04:56:44] Epoch = 5 Count = 80 Current_Loss = 1.2375 Time = 11.84
# [2019-05-12 04:56:55] Epoch = 5 Count = 100 Current_Loss = 0.9123 Time = 11.31
# [2019-05-12 04:57:06] Epoch = 5 Count = 120 Current_Loss = 0.7617 Time = 11.34
# [2019-05-12 04:57:18] Epoch = 5 Count = 140 Current_Loss = 1.4813 Time = 11.33
# [2019-05-12 04:57:29] Epoch = 5 Count = 160 Current_Loss = 0.9198 Time = 11.36
# [2019-05-12 04:57:41] Epoch = 5 Count = 180 Current_Loss = 0.5141 Time = 11.35
# [2019-05-12 04:57:52] Epoch = 5 Count = 200 Current_Loss = 0.6851 Time = 11.55
# [2019-05-12 04:58:04] Epoch = 5 Count = 220 Current_Loss = 0.8861 Time = 11.82
# [2019-05-12 04:58:15] Epoch = 5 Count = 240 Current_Loss = 0.6056 Time = 11.33
# [2019-05-12 04:58:27] Epoch = 5 Count = 260 Current_Loss = 1.0988 Time = 11.32
# [2019-05-12 04:58:38] Epoch = 5 Count = 280 Current_Loss = 2.1057 Time = 11.35
# [2019-05-12 04:58:49] Epoch = 5 Count = 300 Current_Loss = 0.8226 Time = 11.38
# [2019-05-12 04:59:01] Epoch = 5 Count = 320 Current_Loss = 0.6489 Time = 12.07
# [2019-05-12 04:59:13] Epoch = 5 Count = 340 Current_Loss = 0.7164 Time = 11.51
# [2019-05-12 04:59:25] Epoch = 5 Count = 360 Current_Loss = 0.6716 Time = 11.82
# [2019-05-12 04:59:36] Epoch = 5 Count = 380 Current_Loss = 0.8028 Time = 11.35
# [2019-05-12 04:59:47] Epoch = 5 Count = 400 Current_Loss = 0.9890 Time = 11.38
# [2019-05-12 04:59:59] Epoch = 5 Count = 420 Current_Loss = 0.5826 Time = 11.44
# Saving latest checkpoint
# Saving checkpoint for this epoch
# Performing validation
#
# Average validation accuracy for epoch # 0005 = 0.700965
# Average per class validation accuracies for epoch # 0005:
# Animal = 0.950000
# Archway = 0.900000
# Bicyclist = 0.572942
# Bridge = 0.950000
# Building = 0.782499
# Car = 0.818269
# CartLuggagePram = 0.750000
# Child = 0.950000
# Column_Pole = 0.109564
# Fence = 0.701110
# LaneMkgsDriv = 0.108194
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.297909
# MotorcycleScooter = 0.950000
# OtherMoving = 0.700000
# ParkingBlock = 0.750000
# Pedestrian = 0.473572
# Road = 0.978361
# RoadShoulder = 0.950000
# Sidewalk = 0.472368
# SignSymbol = 0.353846
# Sky = 0.965778
# SUVPickupTruck = 0.741243
# TrafficCone = 1.000000
# TrafficLight = 0.534799
# Train = 1.000000
# Tree = 0.764061
# Truck_Bus = 0.800000
# Tunnel = 1.000000
# VegetationMisc = 0.787164
# Void = 0.185085
# Wall = 0.498225
# Validation precision =  0.780795682365543
# Validation recall =  0.7009649276733398
# Validation F1 score =  0.6994365877143471
# Validation IoU score =  0.2460306613842534
# [2019-05-12 05:00:23] Remaining training time = 11 hours 20 minutes 19 seconds
#
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 05:00:35] Epoch = 6 Count = 20 Current_Loss = 1.0335 Time = 11.73
# [2019-05-12 05:00:47] Epoch = 6 Count = 40 Current_Loss = 0.7072 Time = 11.78
# [2019-05-12 05:00:58] Epoch = 6 Count = 60 Current_Loss = 1.1888 Time = 11.47
# [2019-05-12 05:01:10] Epoch = 6 Count = 80 Current_Loss = 0.7175 Time = 11.44
# [2019-05-12 05:01:21] Epoch = 6 Count = 100 Current_Loss = 0.6137 Time = 11.38
# [2019-05-12 05:01:33] Epoch = 6 Count = 120 Current_Loss = 0.8380 Time = 11.41
# [2019-05-12 05:01:44] Epoch = 6 Count = 140 Current_Loss = 0.4964 Time = 11.64
# [2019-05-12 05:01:56] Epoch = 6 Count = 160 Current_Loss = 0.4940 Time = 11.69
# [2019-05-12 05:02:08] Epoch = 6 Count = 180 Current_Loss = 0.7080 Time = 11.74
# [2019-05-12 05:02:19] Epoch = 6 Count = 200 Current_Loss = 0.8397 Time = 11.41
# [2019-05-12 05:02:31] Epoch = 6 Count = 220 Current_Loss = 1.2530 Time = 11.43
# [2019-05-12 05:02:42] Epoch = 6 Count = 240 Current_Loss = 0.7192 Time = 11.39
# [2019-05-12 05:02:53] Epoch = 6 Count = 260 Current_Loss = 0.8201 Time = 11.36
# [2019-05-12 05:03:05] Epoch = 6 Count = 280 Current_Loss = 0.5143 Time = 11.35
# [2019-05-12 05:03:16] Epoch = 6 Count = 300 Current_Loss = 0.6538 Time = 11.65
# [2019-05-12 05:03:28] Epoch = 6 Count = 320 Current_Loss = 0.8367 Time = 11.71
# [2019-05-12 05:03:39] Epoch = 6 Count = 340 Current_Loss = 0.4103 Time = 11.37
# [2019-05-12 05:03:51] Epoch = 6 Count = 360 Current_Loss = 0.5649 Time = 11.40
# [2019-05-12 05:04:02] Epoch = 6 Count = 380 Current_Loss = 0.4555 Time = 11.44
# [2019-05-12 05:04:14] Epoch = 6 Count = 400 Current_Loss = 0.7797 Time = 11.98
# [2019-05-12 05:04:26] Epoch = 6 Count = 420 Current_Loss = 0.5368 Time = 11.37
# Saving latest checkpoint
# Performing validation
#
# Average validation accuracy for epoch # 0006 = 0.754378
# Average per class validation accuracies for epoch # 0006:
# Animal = 0.950000
# Archway = 0.900000
# Bicyclist = 0.619911
# Bridge = 0.950000
# Building = 0.893223
# Car = 0.809070
# CartLuggagePram = 0.750000
# Child = 0.950000
# Column_Pole = 0.144463
# Fence = 0.716906
# LaneMkgsDriv = 0.153245
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.335899
# MotorcycleScooter = 0.950000
# OtherMoving = 0.730700
# ParkingBlock = 0.750000
# Pedestrian = 0.428834
# Road = 0.958379
# RoadShoulder = 0.950000
# Sidewalk = 0.534246
# SignSymbol = 0.372796
# Sky = 0.945302
# SUVPickupTruck = 0.810059
# TrafficCone = 1.000000
# TrafficLight = 0.581471
# Train = 1.000000
# Tree = 0.828063
# Truck_Bus = 0.800000
# Tunnel = 1.000000
# VegetationMisc = 0.769954
# Void = 0.161888
# Wall = 0.400344
# Validation precision =  0.8341302117111598
# Validation recall =  0.7543781280517579
# Validation F1 score =  0.7638138949047915
# Validation IoU score =  0.28088998798104525
# [2019-05-12 05:04:46] Remaining training time = 11 hours 10 minutes 33 seconds
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# [2019-05-12 05:04:58] Epoch = 7 Count = 20 Current_Loss = 0.7019 Time = 11.40
# [2019-05-12 05:05:10] Epoch = 7 Count = 40 Current_Loss = 0.4348 Time = 11.44
# [2019-05-12 05:05:21] Epoch = 7 Count = 60 Current_Loss = 0.5104 Time = 11.47
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 05:05:33] Epoch = 7 Count = 80 Current_Loss = 0.3518 Time = 11.39
# [2019-05-12 05:05:44] Epoch = 7 Count = 100 Current_Loss = 0.3945 Time = 11.35
# [2019-05-12 05:05:56] Epoch = 7 Count = 120 Current_Loss = 0.5742 Time = 11.49
# [2019-05-12 05:06:07] Epoch = 7 Count = 140 Current_Loss = 0.5685 Time = 11.81
# [2019-05-12 05:06:19] Epoch = 7 Count = 160 Current_Loss = 0.6745 Time = 11.35
# [2019-05-12 05:06:30] Epoch = 7 Count = 180 Current_Loss = 0.8493 Time = 11.36
# [2019-05-12 05:06:42] Epoch = 7 Count = 200 Current_Loss = 0.5400 Time = 11.44
# [2019-05-12 05:06:53] Epoch = 7 Count = 220 Current_Loss = 0.8311 Time = 11.75
# [2019-05-12 05:07:05] Epoch = 7 Count = 240 Current_Loss = 0.4466 Time = 11.39
# [2019-05-12 05:07:16] Epoch = 7 Count = 260 Current_Loss = 0.8382 Time = 11.52
# [2019-05-12 05:07:28] Epoch = 7 Count = 280 Current_Loss = 0.7469 Time = 11.79
# [2019-05-12 05:07:39] Epoch = 7 Count = 300 Current_Loss = 1.1267 Time = 11.36
# [2019-05-12 05:07:51] Epoch = 7 Count = 320 Current_Loss = 0.5503 Time = 11.39
# [2019-05-12 05:08:02] Epoch = 7 Count = 340 Current_Loss = 0.5432 Time = 11.40
# [2019-05-12 05:08:13] Epoch = 7 Count = 360 Current_Loss = 0.5312 Time = 11.36
# [2019-05-12 05:08:25] Epoch = 7 Count = 380 Current_Loss = 0.5962 Time = 11.37
# [2019-05-12 05:08:36] Epoch = 7 Count = 400 Current_Loss = 0.5277 Time = 11.52
# [2019-05-12 05:08:48] Epoch = 7 Count = 420 Current_Loss = 0.9300 Time = 11.83
# Saving latest checkpoint
# Performing validation
#
# Average validation accuracy for epoch # 0007 = 0.772997
# Average per class validation accuracies for epoch # 0007:
# Animal = 0.950000
# Archway = 0.900000
# Bicyclist = 0.604992
# Bridge = 0.950000
# Building = 0.897887
# Car = 0.836202
# CartLuggagePram = 0.750000
# Child = 0.950000
# Column_Pole = 0.162774
# Fence = 0.727858
# LaneMkgsDriv = 0.128472
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.339903
# MotorcycleScooter = 0.950000
# OtherMoving = 0.736335
# ParkingBlock = 0.750000
# Pedestrian = 0.532415
# Road = 0.950777
# RoadShoulder = 0.950000
# Sidewalk = 0.573753
# SignSymbol = 0.385677
# Sky = 0.976182
# SUVPickupTruck = 0.837623
# TrafficCone = 1.000000
# TrafficLight = 0.582009
# Train = 1.000000
# Tree = 0.759478
# Truck_Bus = 0.800000
# Tunnel = 1.000000
# VegetationMisc = 0.824802
# Void = 0.194013
# Wall = 0.530215
# Validation precision =  0.8459766557339667
# Validation recall =  0.7729969024658203
# Validation F1 score =  0.78511224101721
# Validation IoU score =  0.30031711967226454
# [2019-05-12 05:09:08] Remaining training time = 11 hours 0 minutes 11 seconds
#
# [2019-05-12 05:09:20] Epoch = 8 Count = 20 Current_Loss = 0.4286 Time = 11.96
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 05:09:32] Epoch = 8 Count = 40 Current_Loss = 0.6974 Time = 11.47
# [2019-05-12 05:09:43] Epoch = 8 Count = 60 Current_Loss = 0.5906 Time = 11.40
# [2019-05-12 05:09:55] Epoch = 8 Count = 80 Current_Loss = 0.3428 Time = 11.38
# [2019-05-12 05:10:06] Epoch = 8 Count = 100 Current_Loss = 0.7105 Time = 11.96
# [2019-05-12 05:10:18] Epoch = 8 Count = 120 Current_Loss = 1.1747 Time = 11.34
# [2019-05-12 05:10:29] Epoch = 8 Count = 140 Current_Loss = 0.3577 Time = 11.37
# [2019-05-12 05:10:41] Epoch = 8 Count = 160 Current_Loss = 0.4901 Time = 11.34
# [2019-05-12 05:10:52] Epoch = 8 Count = 180 Current_Loss = 0.5680 Time = 11.37
# [2019-05-12 05:11:03] Epoch = 8 Count = 200 Current_Loss = 0.3926 Time = 11.41
# [2019-05-12 05:11:15] Epoch = 8 Count = 220 Current_Loss = 0.6217 Time = 11.34
# [2019-05-12 05:11:27] Epoch = 8 Count = 240 Current_Loss = 1.0920 Time = 11.98
# [2019-05-12 05:11:38] Epoch = 8 Count = 260 Current_Loss = 0.4634 Time = 11.37
# [2019-05-12 05:11:49] Epoch = 8 Count = 280 Current_Loss = 0.5488 Time = 11.40
# [2019-05-12 05:12:01] Epoch = 8 Count = 300 Current_Loss = 0.3665 Time = 11.70
# [2019-05-12 05:12:12] Epoch = 8 Count = 320 Current_Loss = 1.0923 Time = 11.35
# [2019-05-12 05:12:24] Epoch = 8 Count = 340 Current_Loss = 0.5221 Time = 11.33
# [2019-05-12 05:12:35] Epoch = 8 Count = 360 Current_Loss = 0.9727 Time = 11.39
# [2019-05-12 05:12:47] Epoch = 8 Count = 380 Current_Loss = 0.6366 Time = 11.97
# [2019-05-12 05:12:58] Epoch = 8 Count = 400 Current_Loss = 0.4820 Time = 11.36
# [2019-05-12 05:13:10] Epoch = 8 Count = 420 Current_Loss = 0.3678 Time = 11.36
# Saving latest checkpoint
# Performing validation
#
# Average validation accuracy for epoch # 0008 = 0.785965
# Average per class validation accuracies for epoch # 0008:
# Animal = 0.950000
# Archway = 0.900000
# Bicyclist = 0.634333
# Bridge = 0.950000
# Building = 0.873566
# Car = 0.874218
# CartLuggagePram = 0.750000
# Child = 0.950000
# Column_Pole = 0.199994
# Fence = 0.746928
# LaneMkgsDriv = 0.230516
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.382545
# MotorcycleScooter = 0.950000
# OtherMoving = 0.745583
# ParkingBlock = 0.750000
# Pedestrian = 0.506340
# Road = 0.924500
# RoadShoulder = 0.950000
# Sidewalk = 0.619838
# SignSymbol = 0.369814
# Sky = 0.961545
# SUVPickupTruck = 0.813383
# TrafficCone = 1.000000
# TrafficLight = 0.676693
# Train = 1.000000
# Tree = 0.877795
# Truck_Bus = 0.800000
# Tunnel = 1.000000
# VegetationMisc = 0.845373
# Void = 0.204639
# Wall = 0.567689
# Validation precision =  0.8435074014485359
# Validation recall =  0.7859653472900391
# Validation F1 score =  0.7937383648953954
# Validation IoU score =  0.3308369509467569
# [2019-05-12 05:13:29] Remaining training time = 10 hours 57 minutes 4 seconds
#
# [2019-05-12 05:13:41] Epoch = 9 Count = 20 Current_Loss = 0.7448 Time = 11.35
# [2019-05-12 05:13:53] Epoch = 9 Count = 40 Current_Loss = 0.6334 Time = 11.34
# [2019-05-12 05:14:05] Epoch = 9 Count = 60 Current_Loss = 0.5088 Time = 11.90
# [2019-05-12 05:14:16] Epoch = 9 Count = 80 Current_Loss = 0.5549 Time = 11.40
# [2019-05-12 05:14:28] Epoch = 9 Count = 100 Current_Loss = 0.5087 Time = 11.73
# [2019-05-12 05:14:39] Epoch = 9 Count = 120 Current_Loss = 0.3726 Time = 11.66
# [2019-05-12 05:14:51] Epoch = 9 Count = 140 Current_Loss = 0.2660 Time = 11.31
# [2019-05-12 05:15:02] Epoch = 9 Count = 160 Current_Loss = 0.5441 Time = 11.34
# [2019-05-12 05:15:13] Epoch = 9 Count = 180 Current_Loss = 0.4943 Time = 11.35
# [2019-05-12 05:15:25] Epoch = 9 Count = 200 Current_Loss = 0.2829 Time = 11.89
# [2019-05-12 05:15:37] Epoch = 9 Count = 220 Current_Loss = 0.3536 Time = 11.43
# [2019-05-12 05:15:48] Epoch = 9 Count = 240 Current_Loss = 0.2724 Time = 11.33
# [2019-05-12 05:15:59] Epoch = 9 Count = 260 Current_Loss = 0.3949 Time = 11.34
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 05:16:11] Epoch = 9 Count = 280 Current_Loss = 0.4044 Time = 11.36
# [2019-05-12 05:16:22] Epoch = 9 Count = 300 Current_Loss = 0.4219 Time = 11.33
# [2019-05-12 05:16:34] Epoch = 9 Count = 320 Current_Loss = 0.3346 Time = 11.40
# [2019-05-12 05:16:45] Epoch = 9 Count = 340 Current_Loss = 1.7228 Time = 11.89
# [2019-05-12 05:16:57] Epoch = 9 Count = 360 Current_Loss = 0.7320 Time = 11.56
# [2019-05-12 05:17:09] Epoch = 9 Count = 380 Current_Loss = 0.2470 Time = 11.60
# [2019-05-12 05:17:20] Epoch = 9 Count = 400 Current_Loss = 0.7009 Time = 11.34
# [2019-05-12 05:17:31] Epoch = 9 Count = 420 Current_Loss = 0.5401 Time = 11.36
# Saving latest checkpoint
# Performing validation
#
# Average validation accuracy for epoch # 0009 = 0.805377
# Average per class validation accuracies for epoch # 0009:
# Animal = 0.950000
# Archway = 0.900000
# Bicyclist = 0.606596
# Bridge = 0.950000
# Building = 0.912265
# Car = 0.887699
# CartLuggagePram = 0.750000
# Child = 0.950000
# Column_Pole = 0.240543
# Fence = 0.799896
# LaneMkgsDriv = 0.313346
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.399953
# MotorcycleScooter = 0.950000
# OtherMoving = 0.726334
# ParkingBlock = 0.771595
# Pedestrian = 0.598323
# Road = 0.951354
# RoadShoulder = 0.950000
# Sidewalk = 0.688260
# SignSymbol = 0.365877
# Sky = 0.946735
# SUVPickupTruck = 0.810238
# TrafficCone = 1.000000
# TrafficLight = 0.688152
# Train = 1.000000
# Tree = 0.863466
# Truck_Bus = 0.800000
# Tunnel = 1.000000
# VegetationMisc = 0.833845
# Void = 0.216502
# Wall = 0.595064
# Validation precision =  0.8540554576372579
# Validation recall =  0.805377197265625
# Validation F1 score =  0.8127674886605059
# Validation IoU score =  0.3543855455472062
# [2019-05-12 05:17:51] Remaining training time = 10 hours 51 minutes 46 seconds
#
# [2019-05-12 05:18:03] Epoch = 10 Count = 20 Current_Loss = 0.8705 Time = 11.71
# [2019-05-12 05:18:15] Epoch = 10 Count = 40 Current_Loss = 0.3553 Time = 11.57
# [2019-05-12 05:18:26] Epoch = 10 Count = 60 Current_Loss = 0.3097 Time = 11.33
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 05:18:37] Epoch = 10 Count = 80 Current_Loss = 0.4627 Time = 11.36
# [2019-05-12 05:18:49] Epoch = 10 Count = 100 Current_Loss = 0.2529 Time = 11.34
# [2019-05-12 05:19:00] Epoch = 10 Count = 120 Current_Loss = 0.5150 Time = 11.33
# [2019-05-12 05:19:11] Epoch = 10 Count = 140 Current_Loss = 0.5867 Time = 11.37
# [2019-05-12 05:19:23] Epoch = 10 Count = 160 Current_Loss = 0.5181 Time = 11.67
# [2019-05-12 05:19:35] Epoch = 10 Count = 180 Current_Loss = 0.5662 Time = 11.80
# [2019-05-12 05:19:47] Epoch = 10 Count = 200 Current_Loss = 0.3048 Time = 11.89
# [2019-05-12 05:19:58] Epoch = 10 Count = 220 Current_Loss = 0.4031 Time = 11.33
# [2019-05-12 05:20:10] Epoch = 10 Count = 240 Current_Loss = 0.3329 Time = 11.36
# [2019-05-12 05:20:21] Epoch = 10 Count = 260 Current_Loss = 0.6046 Time = 11.36
# [2019-05-12 05:20:32] Epoch = 10 Count = 280 Current_Loss = 0.6835 Time = 11.34
# [2019-05-12 05:20:44] Epoch = 10 Count = 300 Current_Loss = 0.2416 Time = 11.68
# [2019-05-12 05:20:56] Epoch = 10 Count = 320 Current_Loss = 0.6159 Time = 11.63
# [2019-05-12 05:21:07] Epoch = 10 Count = 340 Current_Loss = 0.3939 Time = 11.38
# [2019-05-12 05:21:18] Epoch = 10 Count = 360 Current_Loss = 0.3811 Time = 11.36
# [2019-05-12 05:21:30] Epoch = 10 Count = 380 Current_Loss = 0.5343 Time = 11.35
# [2019-05-12 05:21:41] Epoch = 10 Count = 400 Current_Loss = 0.6053 Time = 11.41
# [2019-05-12 05:21:52] Epoch = 10 Count = 420 Current_Loss = 0.4468 Time = 11.37
# Saving latest checkpoint
# Saving checkpoint for this epoch
# Performing validation
#
# Average validation accuracy for epoch # 0010 = 0.808989
# Average per class validation accuracies for epoch # 0010:
# Animal = 0.950000
# Archway = 0.900000
# Bicyclist = 0.592840
# Bridge = 0.950000
# Building = 0.892118
# Car = 0.871930
# CartLuggagePram = 0.750000
# Child = 0.950000
# Column_Pole = 0.235222
# Fence = 0.712966
# LaneMkgsDriv = 0.235506
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.421253
# MotorcycleScooter = 0.950000
# OtherMoving = 0.744238
# ParkingBlock = 0.767256
# Pedestrian = 0.515813
# Road = 0.954178
# RoadShoulder = 0.952502
# Sidewalk = 0.683725
# SignSymbol = 0.393644
# Sky = 0.962088
# SUVPickupTruck = 0.771297
# TrafficCone = 1.000000
# TrafficLight = 0.687240
# Train = 1.000000
# Tree = 0.855077
# Truck_Bus = 0.800000
# Tunnel = 1.000000
# VegetationMisc = 0.848390
# Void = 0.249114
# Wall = 0.599116
# Validation precision =  0.8537524876642738
# Validation recall =  0.808989143371582
# Validation F1 score =  0.8161868258613147
# Validation IoU score =  0.34842324345392506
# [2019-05-12 05:22:17] Remaining training time = 10 hours 59 minutes 18 seconds
#
# [2019-05-12 05:22:29] Epoch = 11 Count = 20 Current_Loss = 0.2494 Time = 11.30
# [2019-05-12 05:22:40] Epoch = 11 Count = 40 Current_Loss = 0.2565 Time = 11.35
# [2019-05-12 05:22:52] Epoch = 11 Count = 60 Current_Loss = 0.3548 Time = 11.31
# [2019-05-12 05:23:03] Epoch = 11 Count = 80 Current_Loss = 0.3715 Time = 11.36
# [2019-05-12 05:23:14] Epoch = 11 Count = 100 Current_Loss = 0.3372 Time = 11.32
# [2019-05-12 05:23:26] Epoch = 11 Count = 120 Current_Loss = 0.6421 Time = 11.77
# [2019-05-12 05:23:37] Epoch = 11 Count = 140 Current_Loss = 0.5082 Time = 11.50
# [2019-05-12 05:23:49] Epoch = 11 Count = 160 Current_Loss = 0.6399 Time = 11.33
# [2019-05-12 05:24:00] Epoch = 11 Count = 180 Current_Loss = 0.4336 Time = 11.32
# [2019-05-12 05:24:11] Epoch = 11 Count = 200 Current_Loss = 0.9982 Time = 11.34
# [2019-05-12 05:24:23] Epoch = 11 Count = 220 Current_Loss = 0.2574 Time = 11.34
# [2019-05-12 05:24:34] Epoch = 11 Count = 240 Current_Loss = 0.2844 Time = 11.36
# [2019-05-12 05:24:46] Epoch = 11 Count = 260 Current_Loss = 0.4144 Time = 11.72
# [2019-05-12 05:24:58] Epoch = 11 Count = 280 Current_Loss = 0.3313 Time = 11.82
# [2019-05-12 05:25:09] Epoch = 11 Count = 300 Current_Loss = 0.6476 Time = 11.35
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 05:25:20] Epoch = 11 Count = 320 Current_Loss = 0.3047 Time = 11.33
# [2019-05-12 05:25:32] Epoch = 11 Count = 340 Current_Loss = 0.3177 Time = 11.34
# [2019-05-12 05:25:43] Epoch = 11 Count = 360 Current_Loss = 0.4939 Time = 11.36
# [2019-05-12 05:25:54] Epoch = 11 Count = 380 Current_Loss = 0.3538 Time = 11.34
# [2019-05-12 05:26:06] Epoch = 11 Count = 400 Current_Loss = 0.6882 Time = 11.71
# [2019-05-12 05:26:18] Epoch = 11 Count = 420 Current_Loss = 0.6241 Time = 11.59
# Saving latest checkpoint
# Performing validation
#
# Average validation accuracy for epoch # 0011 = 0.810529
# Average per class validation accuracies for epoch # 0011:
# Animal = 0.950000
# Archway = 0.900000
# Bicyclist = 0.620970
# Bridge = 0.950000
# Building = 0.942512
# Car = 0.818029
# CartLuggagePram = 0.750000
# Child = 0.950000
# Column_Pole = 0.191503
# Fence = 0.752977
# LaneMkgsDriv = 0.177996
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.400738
# MotorcycleScooter = 0.950000
# OtherMoving = 0.720369
# ParkingBlock = 0.769982
# Pedestrian = 0.436410
# Road = 0.945552
# RoadShoulder = 0.957324
# Sidewalk = 0.664570
# SignSymbol = 0.391133
# Sky = 0.972474
# SUVPickupTruck = 0.800374
# TrafficCone = 1.000000
# TrafficLight = 0.622142
# Train = 1.000000
# Tree = 0.782005
# Truck_Bus = 0.829907
# Tunnel = 1.000000
# VegetationMisc = 0.819541
# Void = 0.237202
# Wall = 0.585231
# Validation precision =  0.8720129888974574
# Validation recall =  0.810528564453125
# Validation F1 score =  0.8238329369416808
# Validation IoU score =  0.3493061530470602
# [2019-05-12 05:26:37] Remaining training time = 10 hours 40 minutes 38 seconds
#
# [2019-05-12 05:26:49] Epoch = 12 Count = 20 Current_Loss = 0.4440 Time = 11.44
# [2019-05-12 05:27:01] Epoch = 12 Count = 40 Current_Loss = 0.4106 Time = 11.32
# [2019-05-12 05:27:12] Epoch = 12 Count = 60 Current_Loss = 0.2948 Time = 11.65
# [2019-05-12 05:27:24] Epoch = 12 Count = 80 Current_Loss = 0.2463 Time = 11.52
# [2019-05-12 05:27:36] Epoch = 12 Count = 100 Current_Loss = 0.4168 Time = 11.80
# [2019-05-12 05:27:47] Epoch = 12 Count = 120 Current_Loss = 0.3049 Time = 11.35
# [2019-05-12 05:27:58] Epoch = 12 Count = 140 Current_Loss = 0.4692 Time = 11.34
# [2019-05-12 05:28:10] Epoch = 12 Count = 160 Current_Loss = 0.2991 Time = 11.35
# [2019-05-12 05:28:21] Epoch = 12 Count = 180 Current_Loss = 0.2683 Time = 11.37
# [2019-05-12 05:28:32] Epoch = 12 Count = 200 Current_Loss = 0.4273 Time = 11.37
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 05:28:44] Epoch = 12 Count = 220 Current_Loss = 0.5899 Time = 11.52
# [2019-05-12 05:28:56] Epoch = 12 Count = 240 Current_Loss = 0.2027 Time = 11.83
# [2019-05-12 05:29:07] Epoch = 12 Count = 260 Current_Loss = 0.4282 Time = 11.36
# [2019-05-12 05:29:19] Epoch = 12 Count = 280 Current_Loss = 0.4377 Time = 11.35
# [2019-05-12 05:29:30] Epoch = 12 Count = 300 Current_Loss = 0.2489 Time = 11.33
# [2019-05-12 05:29:41] Epoch = 12 Count = 320 Current_Loss = 0.4134 Time = 11.35
# [2019-05-12 05:29:53] Epoch = 12 Count = 340 Current_Loss = 0.2765 Time = 11.35
# [2019-05-12 05:30:05] Epoch = 12 Count = 360 Current_Loss = 0.3303 Time = 12.10
# [2019-05-12 05:30:16] Epoch = 12 Count = 380 Current_Loss = 0.3646 Time = 11.80
# [2019-05-12 05:30:28] Epoch = 12 Count = 400 Current_Loss = 0.7123 Time = 11.36
# [2019-05-12 05:30:39] Epoch = 12 Count = 420 Current_Loss = 0.6150 Time = 11.35
# Saving latest checkpoint
# Performing validation
#
# Average validation accuracy for epoch # 0012 = 0.818055
# Average per class validation accuracies for epoch # 0012:
# Animal = 0.950000
# Archway = 0.900000
# Bicyclist = 0.639437
# Bridge = 0.950000
# Building = 0.909785
# Car = 0.881850
# CartLuggagePram = 0.750000
# Child = 0.950000
# Column_Pole = 0.259900
# Fence = 0.721256
# LaneMkgsDriv = 0.211402
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.439817
# MotorcycleScooter = 0.950000
# OtherMoving = 0.737780
# ParkingBlock = 0.779427
# Pedestrian = 0.549725
# Road = 0.965210
# RoadShoulder = 0.973761
# Sidewalk = 0.638640
# SignSymbol = 0.414785
# Sky = 0.942358
# SUVPickupTruck = 0.855306
# TrafficCone = 1.000000
# TrafficLight = 0.638650
# Train = 1.000000
# Tree = 0.834857
# Truck_Bus = 0.803157
# Tunnel = 1.000000
# VegetationMisc = 0.850718
# Void = 0.295413
# Wall = 0.642967
# Validation precision =  0.8498639448817882
# Validation recall =  0.8180547714233398
# Validation F1 score =  0.8202388456729489
# Validation IoU score =  0.369436878684657
# [2019-05-12 05:30:59] Remaining training time = 10 hours 38 minutes 53 seconds
#
# [2019-05-12 05:31:11] Epoch = 13 Count = 20 Current_Loss = 0.2566 Time = 11.35
# [2019-05-12 05:31:22] Epoch = 13 Count = 40 Current_Loss = 0.5921 Time = 11.34
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 05:31:34] Epoch = 13 Count = 60 Current_Loss = 0.2883 Time = 11.96
# [2019-05-12 05:31:45] Epoch = 13 Count = 80 Current_Loss = 0.2021 Time = 11.37
# [2019-05-12 05:31:57] Epoch = 13 Count = 100 Current_Loss = 0.2492 Time = 11.35
# [2019-05-12 05:32:08] Epoch = 13 Count = 120 Current_Loss = 0.4585 Time = 11.33
# [2019-05-12 05:32:20] Epoch = 13 Count = 140 Current_Loss = 0.3046 Time = 11.70
# [2019-05-12 05:32:31] Epoch = 13 Count = 160 Current_Loss = 0.3480 Time = 11.36
# [2019-05-12 05:32:43] Epoch = 13 Count = 180 Current_Loss = 0.4771 Time = 11.38
# [2019-05-12 05:32:54] Epoch = 13 Count = 200 Current_Loss = 0.5256 Time = 11.97
# [2019-05-12 05:33:06] Epoch = 13 Count = 220 Current_Loss = 0.5591 Time = 11.36
# [2019-05-12 05:33:17] Epoch = 13 Count = 240 Current_Loss = 0.4143 Time = 11.37
# [2019-05-12 05:33:29] Epoch = 13 Count = 260 Current_Loss = 0.2967 Time = 11.36
# [2019-05-12 05:33:40] Epoch = 13 Count = 280 Current_Loss = 0.3273 Time = 11.35
# [2019-05-12 05:33:51] Epoch = 13 Count = 300 Current_Loss = 0.3140 Time = 11.37
# [2019-05-12 05:34:03] Epoch = 13 Count = 320 Current_Loss = 0.2184 Time = 11.37
# [2019-05-12 05:34:15] Epoch = 13 Count = 340 Current_Loss = 0.7199 Time = 11.95
# [2019-05-12 05:34:26] Epoch = 13 Count = 360 Current_Loss = 0.3249 Time = 11.35
# [2019-05-12 05:34:37] Epoch = 13 Count = 380 Current_Loss = 0.2066 Time = 11.35
# [2019-05-12 05:34:49] Epoch = 13 Count = 400 Current_Loss = 0.2798 Time = 11.35
# [2019-05-12 05:35:00] Epoch = 13 Count = 420 Current_Loss = 0.8473 Time = 11.35
# Saving latest checkpoint
# Performing validation
#
# Average validation accuracy for epoch # 0013 = 0.788073
# Average per class validation accuracies for epoch # 0013:
# Animal = 0.950000
# Archway = 0.900000
# Bicyclist = 0.599975
# Bridge = 0.950000
# Building = 0.838834
# Car = 0.900975
# CartLuggagePram = 0.750000
# Child = 0.950000
# Column_Pole = 0.226376
# Fence = 0.796857
# LaneMkgsDriv = 0.314306
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.495172
# MotorcycleScooter = 0.950000
# OtherMoving = 0.730639
# ParkingBlock = 0.781080
# Pedestrian = 0.592000
# Road = 0.924362
# RoadShoulder = 0.957862
# Sidewalk = 0.621597
# SignSymbol = 0.419133
# Sky = 0.948636
# SUVPickupTruck = 0.831091
# TrafficCone = 1.000000
# TrafficLight = 0.697524
# Train = 1.000000
# Tree = 0.854106
# Truck_Bus = 0.808488
# Tunnel = 1.000000
# VegetationMisc = 0.836951
# Void = 0.308431
# Wall = 0.584722
# Validation precision =  0.8176208807139392
# Validation recall =  0.7880729675292969
# Validation F1 score =  0.7837180167888217
# Validation IoU score =  0.36355287660879165
# [2019-05-12 05:35:21] Remaining training time = 10 hours 36 minutes 38 seconds
#
# [2019-05-12 05:35:34] Epoch = 14 Count = 20 Current_Loss = 0.4115 Time = 11.95
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 05:35:45] Epoch = 14 Count = 40 Current_Loss = 0.3550 Time = 11.38
# [2019-05-12 05:35:56] Epoch = 14 Count = 60 Current_Loss = 0.2301 Time = 11.34
# [2019-05-12 05:36:08] Epoch = 14 Count = 80 Current_Loss = 0.4959 Time = 11.36
# [2019-05-12 05:36:19] Epoch = 14 Count = 100 Current_Loss = 0.2715 Time = 11.31
# [2019-05-12 05:36:30] Epoch = 14 Count = 120 Current_Loss = 0.6406 Time = 11.35
# [2019-05-12 05:36:42] Epoch = 14 Count = 140 Current_Loss = 1.3686 Time = 11.37
# [2019-05-12 05:36:54] Epoch = 14 Count = 160 Current_Loss = 0.4017 Time = 11.91
# [2019-05-12 05:37:05] Epoch = 14 Count = 180 Current_Loss = 1.7934 Time = 11.42
# [2019-05-12 05:37:16] Epoch = 14 Count = 200 Current_Loss = 0.4138 Time = 11.33
# [2019-05-12 05:37:28] Epoch = 14 Count = 220 Current_Loss = 0.3449 Time = 11.69
# [2019-05-12 05:37:39] Epoch = 14 Count = 240 Current_Loss = 0.4241 Time = 11.39
# [2019-05-12 05:37:51] Epoch = 14 Count = 260 Current_Loss = 0.3587 Time = 11.34
# [2019-05-12 05:38:02] Epoch = 14 Count = 280 Current_Loss = 0.3085 Time = 11.40
# [2019-05-12 05:38:14] Epoch = 14 Count = 300 Current_Loss = 0.3925 Time = 11.88
# [2019-05-12 05:38:26] Epoch = 14 Count = 320 Current_Loss = 0.4890 Time = 11.42
# [2019-05-12 05:38:37] Epoch = 14 Count = 340 Current_Loss = 0.2603 Time = 11.38
# [2019-05-12 05:38:48] Epoch = 14 Count = 360 Current_Loss = 0.5521 Time = 11.38
# [2019-05-12 05:39:00] Epoch = 14 Count = 380 Current_Loss = 0.2880 Time = 11.33
# [2019-05-12 05:39:11] Epoch = 14 Count = 400 Current_Loss = 0.2560 Time = 11.36
# [2019-05-12 05:39:22] Epoch = 14 Count = 420 Current_Loss = 0.2507 Time = 11.36
# Saving latest checkpoint
# Performing validation
#
# Average validation accuracy for epoch # 0014 = 0.828195
# Average per class validation accuracies for epoch # 0014:
# Animal = 0.950000
# Archway = 0.900000
# Bicyclist = 0.657599
# Bridge = 0.950000
# Building = 0.889950
# Car = 0.847101
# CartLuggagePram = 0.750000
# Child = 0.950000
# Column_Pole = 0.285363
# Fence = 0.721207
# LaneMkgsDriv = 0.216784
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.439764
# MotorcycleScooter = 0.950000
# OtherMoving = 0.761642
# ParkingBlock = 0.782385
# Pedestrian = 0.604150
# Road = 0.950623
# RoadShoulder = 0.984188
# Sidewalk = 0.661757
# SignSymbol = 0.426505
# Sky = 0.967845
# SUVPickupTruck = 0.875148
# TrafficCone = 1.000000
# TrafficLight = 0.702708
# Train = 1.000000
# Tree = 0.804275
# Truck_Bus = 0.813885
# Tunnel = 1.000000
# VegetationMisc = 0.893609
# Void = 0.263878
# Wall = 0.689429
# Validation precision =  0.8612343950472748
# Validation recall =  0.8281951904296875
# Validation F1 score =  0.8339906732285749
# Validation IoU score =  0.38453815652905937
# [2019-05-12 05:39:43] Remaining training time = 10 hours 32 minutes 11 seconds
#
# [2019-05-12 05:39:55] Epoch = 15 Count = 20 Current_Loss = 0.2695 Time = 11.32
# [2019-05-12 05:40:07] Epoch = 15 Count = 40 Current_Loss = 0.2578 Time = 11.33
# [2019-05-12 05:40:18] Epoch = 15 Count = 60 Current_Loss = 0.2687 Time = 11.61
# [2019-05-12 05:40:30] Epoch = 15 Count = 80 Current_Loss = 0.3729 Time = 11.80
# [2019-05-12 05:40:41] Epoch = 15 Count = 100 Current_Loss = 0.4199 Time = 11.35
# [2019-05-12 05:40:53] Epoch = 15 Count = 120 Current_Loss = 0.4237 Time = 11.76
# [2019-05-12 05:41:05] Epoch = 15 Count = 140 Current_Loss = 0.2408 Time = 11.54
# [2019-05-12 05:41:16] Epoch = 15 Count = 160 Current_Loss = 0.4273 Time = 11.32
# [2019-05-12 05:41:27] Epoch = 15 Count = 180 Current_Loss = 0.3239 Time = 11.31
# [2019-05-12 05:41:39] Epoch = 15 Count = 200 Current_Loss = 0.2932 Time = 11.35
# [2019-05-12 05:41:50] Epoch = 15 Count = 220 Current_Loss = 0.2584 Time = 11.37
# ...
# [2019-05-12 15:52:30] Epoch = 154 Count = 260 Current_Loss = 0.1575 Time = 11.30
# [2019-05-12 15:52:42] Epoch = 154 Count = 280 Current_Loss = 0.1465 Time = 11.61
# [2019-05-12 15:52:53] Epoch = 154 Count = 300 Current_Loss = 0.1169 Time = 11.51
# [2019-05-12 15:53:05] Epoch = 154 Count = 320 Current_Loss = 0.1067 Time = 11.60
# [2019-05-12 15:53:16] Epoch = 154 Count = 340 Current_Loss = 0.1214 Time = 11.28
# [2019-05-12 15:53:27] Epoch = 154 Count = 360 Current_Loss = 0.1385 Time = 11.29
# [2019-05-12 15:53:39] Epoch = 154 Count = 380 Current_Loss = 0.0836 Time = 11.23
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 15:53:50] Epoch = 154 Count = 400 Current_Loss = 0.1085 Time = 11.28
# [2019-05-12 15:54:02] Epoch = 154 Count = 420 Current_Loss = 0.1280 Time = 11.52
# Saving latest checkpoint
# Performing validation
#
# Average validation accuracy for epoch # 0154 = 0.862843
# Average per class validation accuracies for epoch # 0154:
# Animal = 0.987462
# Archway = 0.900000
# Bicyclist = 0.672631
# Bridge = 0.982073
# Building = 0.913530
# Car = 0.861249
# CartLuggagePram = 0.784465
# Child = 0.950000
# Column_Pole = 0.459573
# Fence = 0.793623
# LaneMkgsDriv = 0.336634
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.746540
# MotorcycleScooter = 0.954960
# OtherMoving = 0.876932
# ParkingBlock = 0.883623
# Pedestrian = 0.657324
# Road = 0.951974
# RoadShoulder = 0.991876
# Sidewalk = 0.803036
# SignSymbol = 0.547323
# Sky = 0.952396
# SUVPickupTruck = 0.891892
# TrafficCone = 1.000000
# TrafficLight = 0.862549
# Train = 1.000000
# Tree = 0.808033
# Truck_Bus = 0.867837
# Tunnel = 1.000000
# VegetationMisc = 0.882919
# Void = 0.390881
# Wall = 0.738594
# Validation precision =  0.8859541474683146
# Validation recall =  0.8628427505493164
# Validation F1 score =  0.8654758297770762
# Validation IoU score =  0.5015566325347652
# [2019-05-12 15:54:22] Remaining training time = 0 hours 21 minutes 38 seconds
#
# [2019-05-12 15:54:34] Epoch = 155 Count = 20 Current_Loss = 0.2670 Time = 11.18
# [2019-05-12 15:54:45] Epoch = 155 Count = 40 Current_Loss = 0.0904 Time = 11.21
# [2019-05-12 15:54:56] Epoch = 155 Count = 60 Current_Loss = 0.2243 Time = 11.21
# [2019-05-12 15:55:07] Epoch = 155 Count = 80 Current_Loss = 0.2822 Time = 11.27
# [2019-05-12 15:55:19] Epoch = 155 Count = 100 Current_Loss = 0.1691 Time = 11.35
# [2019-05-12 15:55:30] Epoch = 155 Count = 120 Current_Loss = 0.1423 Time = 11.72
# [2019-05-12 15:55:42] Epoch = 155 Count = 140 Current_Loss = 0.1859 Time = 11.23
# [2019-05-12 15:55:53] Epoch = 155 Count = 160 Current_Loss = 0.1803 Time = 11.25
# [2019-05-12 15:56:04] Epoch = 155 Count = 180 Current_Loss = 0.1181 Time = 11.25
# [2019-05-12 15:56:16] Epoch = 155 Count = 200 Current_Loss = 0.1277 Time = 11.92
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 15:56:27] Epoch = 155 Count = 220 Current_Loss = 0.1062 Time = 11.26
# [2019-05-12 15:56:39] Epoch = 155 Count = 240 Current_Loss = 0.2002 Time = 11.33
# [2019-05-12 15:56:50] Epoch = 155 Count = 260 Current_Loss = 0.1556 Time = 11.75
# [2019-05-12 15:57:02] Epoch = 155 Count = 280 Current_Loss = 0.1968 Time = 11.26
# [2019-05-12 15:57:13] Epoch = 155 Count = 300 Current_Loss = 0.1672 Time = 11.27
# [2019-05-12 15:57:24] Epoch = 155 Count = 320 Current_Loss = 0.2231 Time = 11.21
# [2019-05-12 15:57:35] Epoch = 155 Count = 340 Current_Loss = 0.1763 Time = 11.19
# [2019-05-12 15:57:47] Epoch = 155 Count = 360 Current_Loss = 0.2040 Time = 11.22
# [2019-05-12 15:57:58] Epoch = 155 Count = 380 Current_Loss = 0.2204 Time = 11.27
# [2019-05-12 15:58:10] Epoch = 155 Count = 400 Current_Loss = 0.1210 Time = 11.90
# [2019-05-12 15:58:21] Epoch = 155 Count = 420 Current_Loss = 0.2424 Time = 11.25
# Saving latest checkpoint
# Saving checkpoint for this epoch
# Performing validation
#
# Average validation accuracy for epoch # 0155 = 0.865568
# Average per class validation accuracies for epoch # 0155:
# Animal = 0.990061
# Archway = 0.900000
# Bicyclist = 0.689853
# Bridge = 0.978414
# Building = 0.909273
# Car = 0.878970
# CartLuggagePram = 0.794095
# Child = 0.950951
# Column_Pole = 0.426175
# Fence = 0.820758
# LaneMkgsDriv = 0.340761
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.726433
# MotorcycleScooter = 0.950652
# OtherMoving = 0.863792
# ParkingBlock = 0.875928
# Pedestrian = 0.640093
# Road = 0.946856
# RoadShoulder = 0.991085
# Sidewalk = 0.782244
# SignSymbol = 0.549625
# Sky = 0.931463
# SUVPickupTruck = 0.906869
# TrafficCone = 1.000000
# TrafficLight = 0.813864
# Train = 1.000000
# Tree = 0.837839
# Truck_Bus = 0.873400
# Tunnel = 1.000000
# VegetationMisc = 0.885449
# Void = 0.395043
# Wall = 0.748660
# Validation precision =  0.8879917738672141
# Validation recall =  0.8655683517456054
# Validation F1 score =  0.8680759838118922
# Validation IoU score =  0.5027361175074049
# [2019-05-12 15:58:45] Remaining training time = 0 hours 17 minutes 31 seconds
#
# [2019-05-12 15:58:57] Epoch = 156 Count = 20 Current_Loss = 0.1722 Time = 11.29
# [2019-05-12 15:59:09] Epoch = 156 Count = 40 Current_Loss = 0.2228 Time = 11.24
# [2019-05-12 15:59:20] Epoch = 156 Count = 60 Current_Loss = 0.1507 Time = 11.29
# [2019-05-12 15:59:32] Epoch = 156 Count = 80 Current_Loss = 0.1209 Time = 11.75
# [2019-05-12 15:59:43] Epoch = 156 Count = 100 Current_Loss = 0.1684 Time = 11.21
# [2019-05-12 15:59:54] Epoch = 156 Count = 120 Current_Loss = 0.1818 Time = 11.27
# [2019-05-12 16:00:06] Epoch = 156 Count = 140 Current_Loss = 0.1421 Time = 11.27
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 16:00:17] Epoch = 156 Count = 160 Current_Loss = 0.1231 Time = 11.24
# [2019-05-12 16:00:28] Epoch = 156 Count = 180 Current_Loss = 0.2207 Time = 11.22
# [2019-05-12 16:00:39] Epoch = 156 Count = 200 Current_Loss = 0.1152 Time = 11.27
# [2019-05-12 16:00:51] Epoch = 156 Count = 220 Current_Loss = 0.1579 Time = 11.96
# [2019-05-12 16:01:03] Epoch = 156 Count = 240 Current_Loss = 0.1275 Time = 11.40
# [2019-05-12 16:01:14] Epoch = 156 Count = 260 Current_Loss = 0.1861 Time = 11.47
# [2019-05-12 16:01:26] Epoch = 156 Count = 280 Current_Loss = 0.1697 Time = 12.18
# [2019-05-12 16:01:38] Epoch = 156 Count = 300 Current_Loss = 0.0978 Time = 11.39
# [2019-05-12 16:01:49] Epoch = 156 Count = 320 Current_Loss = 0.1438 Time = 11.36
# [2019-05-12 16:02:00] Epoch = 156 Count = 340 Current_Loss = 0.1298 Time = 11.41
# [2019-05-12 16:02:12] Epoch = 156 Count = 360 Current_Loss = 0.0883 Time = 11.91
# [2019-05-12 16:02:24] Epoch = 156 Count = 380 Current_Loss = 0.2646 Time = 11.37
# [2019-05-12 16:02:35] Epoch = 156 Count = 400 Current_Loss = 0.1178 Time = 11.43
# [2019-05-12 16:02:47] Epoch = 156 Count = 420 Current_Loss = 0.2275 Time = 11.43
# Saving latest checkpoint
# Performing validation
#
# Average validation accuracy for epoch # 0156 = 0.870964
# Average per class validation accuracies for epoch # 0156:
# Animal = 0.978746
# Archway = 0.900000
# Bicyclist = 0.680719
# Bridge = 0.985669
# Building = 0.924812
# Car = 0.896524
# CartLuggagePram = 0.793666
# Child = 0.953541
# Column_Pole = 0.446313
# Fence = 0.783782
# LaneMkgsDriv = 0.374558
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.705422
# MotorcycleScooter = 0.950000
# OtherMoving = 0.850603
# ParkingBlock = 0.853289
# Pedestrian = 0.680413
# Road = 0.930752
# RoadShoulder = 0.984671
# Sidewalk = 0.767472
# SignSymbol = 0.533082
# Sky = 0.956046
# SUVPickupTruck = 0.890260
# TrafficCone = 1.000000
# TrafficLight = 0.870612
# Train = 1.000000
# Tree = 0.828493
# Truck_Bus = 0.850105
# Tunnel = 1.000000
# VegetationMisc = 0.900361
# Void = 0.398922
# Wall = 0.760174
# Validation precision =  0.8940398632629888
# Validation recall =  0.8709638595581055
# Validation F1 score =  0.8751280225442335
# Validation IoU score =  0.5048243391715856
# [2019-05-12 16:03:07] Remaining training time = 0 hours 13 minutes 1 seconds
#
# [2019-05-12 16:03:19] Epoch = 157 Count = 20 Current_Loss = 0.1478 Time = 11.84
# [2019-05-12 16:03:31] Epoch = 157 Count = 40 Current_Loss = 0.2619 Time = 12.07
# [2019-05-12 16:03:43] Epoch = 157 Count = 60 Current_Loss = 0.1731 Time = 11.46
# [2019-05-12 16:03:54] Epoch = 157 Count = 80 Current_Loss = 0.1645 Time = 11.41
# [2019-05-12 16:04:06] Epoch = 157 Count = 100 Current_Loss = 0.1322 Time = 11.41
# [2019-05-12 16:04:17] Epoch = 157 Count = 120 Current_Loss = 0.1359 Time = 11.38
# [2019-05-12 16:04:28] Epoch = 157 Count = 140 Current_Loss = 0.1802 Time = 11.41
# [2019-05-12 16:04:40] Epoch = 157 Count = 160 Current_Loss = 0.1273 Time = 11.46
# [2019-05-12 16:04:52] Epoch = 157 Count = 180 Current_Loss = 0.1549 Time = 12.03
# [2019-05-12 16:05:03] Epoch = 157 Count = 200 Current_Loss = 0.1265 Time = 11.42
# [2019-05-12 16:05:15] Epoch = 157 Count = 220 Current_Loss = 0.0934 Time = 11.41
# [2019-05-12 16:05:26] Epoch = 157 Count = 240 Current_Loss = 0.1074 Time = 11.42
# [2019-05-12 16:05:38] Epoch = 157 Count = 260 Current_Loss = 0.1403 Time = 11.40
# [2019-05-12 16:05:49] Epoch = 157 Count = 280 Current_Loss = 0.1937 Time = 11.35
# [2019-05-12 16:06:00] Epoch = 157 Count = 300 Current_Loss = 0.1887 Time = 11.31
# [2019-05-12 16:06:12] Epoch = 157 Count = 320 Current_Loss = 0.1261 Time = 11.94
# [2019-05-12 16:06:23] Epoch = 157 Count = 340 Current_Loss = 0.1443 Time = 11.32
# [2019-05-12 16:06:35] Epoch = 157 Count = 360 Current_Loss = 0.2115 Time = 11.91
# [2019-05-12 16:06:47] Epoch = 157 Count = 380 Current_Loss = 0.2057 Time = 11.43
# [2019-05-12 16:06:58] Epoch = 157 Count = 400 Current_Loss = 0.2001 Time = 11.32
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 16:07:09] Epoch = 157 Count = 420 Current_Loss = 0.3134 Time = 11.34
# Saving latest checkpoint
# Performing validation
#
# Average validation accuracy for epoch # 0157 = 0.874802
# Average per class validation accuracies for epoch # 0157:
# Animal = 0.989067
# Archway = 0.900000
# Bicyclist = 0.688075
# Bridge = 0.982154
# Building = 0.921230
# Car = 0.896267
# CartLuggagePram = 0.768367
# Child = 0.950000
# Column_Pole = 0.459069
# Fence = 0.795838
# LaneMkgsDriv = 0.353667
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.719800
# MotorcycleScooter = 0.956119
# OtherMoving = 0.881887
# ParkingBlock = 0.840374
# Pedestrian = 0.687928
# Road = 0.946343
# RoadShoulder = 0.990459
# Sidewalk = 0.774166
# SignSymbol = 0.546346
# Sky = 0.958783
# SUVPickupTruck = 0.910164
# TrafficCone = 1.000000
# TrafficLight = 0.875160
# Train = 1.000000
# Tree = 0.821006
# Truck_Bus = 0.853819
# Tunnel = 1.000000
# VegetationMisc = 0.895871
# Void = 0.389362
# Wall = 0.767864
# Validation precision =  0.8956600205792993
# Validation recall =  0.8748018264770507
# Validation F1 score =  0.8788771983266285
# Validation IoU score =  0.5087835006839339
# [2019-05-12 16:07:31] Remaining training time = 0 hours 8 minutes 46 seconds
#
# [2019-05-12 16:07:43] Epoch = 158 Count = 20 Current_Loss = 0.1658 Time = 11.37
# [2019-05-12 16:07:54] Epoch = 158 Count = 40 Current_Loss = 0.1237 Time = 11.25
# [2019-05-12 16:08:06] Epoch = 158 Count = 60 Current_Loss = 0.2062 Time = 11.29
# [2019-05-12 16:08:17] Epoch = 158 Count = 80 Current_Loss = 0.0847 Time = 11.42
# [2019-05-12 16:08:28] Epoch = 158 Count = 100 Current_Loss = 0.1529 Time = 11.41
# [2019-05-12 16:08:40] Epoch = 158 Count = 120 Current_Loss = 0.1877 Time = 11.28
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 16:08:51] Epoch = 158 Count = 140 Current_Loss = 0.1927 Time = 11.77
# [2019-05-12 16:09:03] Epoch = 158 Count = 160 Current_Loss = 0.1324 Time = 11.34
# [2019-05-12 16:09:14] Epoch = 158 Count = 180 Current_Loss = 0.2456 Time = 11.28
# [2019-05-12 16:09:25] Epoch = 158 Count = 200 Current_Loss = 0.1522 Time = 11.24
# [2019-05-12 16:09:37] Epoch = 158 Count = 220 Current_Loss = 0.2871 Time = 11.27
# [2019-05-12 16:09:48] Epoch = 158 Count = 240 Current_Loss = 0.1224 Time = 11.27
# [2019-05-12 16:09:59] Epoch = 158 Count = 260 Current_Loss = 0.1599 Time = 11.26
# [2019-05-12 16:10:11] Epoch = 158 Count = 280 Current_Loss = 0.1042 Time = 11.69
# [2019-05-12 16:10:22] Epoch = 158 Count = 300 Current_Loss = 0.1180 Time = 11.41
# [2019-05-12 16:10:34] Epoch = 158 Count = 320 Current_Loss = 0.1075 Time = 11.29
# [2019-05-12 16:10:45] Epoch = 158 Count = 340 Current_Loss = 0.2123 Time = 11.27
# [2019-05-12 16:10:56] Epoch = 158 Count = 360 Current_Loss = 0.1372 Time = 11.28
# [2019-05-12 16:11:07] Epoch = 158 Count = 380 Current_Loss = 0.1805 Time = 11.26
# [2019-05-12 16:11:19] Epoch = 158 Count = 400 Current_Loss = 0.1226 Time = 11.25
# [2019-05-12 16:11:30] Epoch = 158 Count = 420 Current_Loss = 0.1555 Time = 11.62
# Saving latest checkpoint
# Performing validation
#
# Average validation accuracy for epoch # 0158 = 0.872913
# Average per class validation accuracies for epoch # 0158:
# Animal = 0.992661
# Archway = 0.900000
# Bicyclist = 0.715094
# Bridge = 0.986170
# Building = 0.926786
# Car = 0.883503
# CartLuggagePram = 0.813054
# Child = 0.950000
# Column_Pole = 0.425591
# Fence = 0.808688
# LaneMkgsDriv = 0.380333
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.709052
# MotorcycleScooter = 0.958436
# OtherMoving = 0.851420
# ParkingBlock = 0.879192
# Pedestrian = 0.662399
# Road = 0.929666
# RoadShoulder = 0.985606
# Sidewalk = 0.774128
# SignSymbol = 0.558496
# Sky = 0.954821
# SUVPickupTruck = 0.902881
# TrafficCone = 1.000000
# TrafficLight = 0.866577
# Train = 1.000000
# Tree = 0.828352
# Truck_Bus = 0.853754
# Tunnel = 1.000000
# VegetationMisc = 0.888854
# Void = 0.356821
# Wall = 0.772307
# Validation precision =  0.8974644170059621
# Validation recall =  0.8729131698608399
# Validation F1 score =  0.8782926510580795
# Validation IoU score =  0.5119257358641203
# [2019-05-12 16:11:52] Remaining training time = 0 hours 4 minutes 20 seconds
#
# [2019-05-12 16:12:04] Epoch = 159 Count = 20 Current_Loss = 0.1988 Time = 11.23
# [2019-05-12 16:12:15] Epoch = 159 Count = 40 Current_Loss = 0.0673 Time = 11.24
# [2019-05-12 16:12:27] Epoch = 159 Count = 60 Current_Loss = 0.2519 Time = 11.73
# [2019-05-12 16:12:38] Epoch = 159 Count = 80 Current_Loss = 0.2156 Time = 11.25
# [2019-05-12 16:12:50] Epoch = 159 Count = 100 Current_Loss = 0.1523 Time = 11.53
# [2019-05-12 16:13:01] Epoch = 159 Count = 120 Current_Loss = 0.1603 Time = 11.51
# [2019-05-12 16:13:12] Epoch = 159 Count = 140 Current_Loss = 0.1118 Time = 11.25
# libpng warning: iCCP: known incorrect sRGB profile
# [2019-05-12 16:13:24] Epoch = 159 Count = 160 Current_Loss = 0.1140 Time = 11.53
# [2019-05-12 16:13:35] Epoch = 159 Count = 180 Current_Loss = 0.2378 Time = 11.37
# [2019-05-12 16:13:46] Epoch = 159 Count = 200 Current_Loss = 0.0674 Time = 11.25
# [2019-05-12 16:13:58] Epoch = 159 Count = 220 Current_Loss = 0.1374 Time = 11.26
# [2019-05-12 16:14:09] Epoch = 159 Count = 240 Current_Loss = 0.1507 Time = 11.47
# [2019-05-12 16:14:21] Epoch = 159 Count = 260 Current_Loss = 0.1004 Time = 11.57
# [2019-05-12 16:14:32] Epoch = 159 Count = 280 Current_Loss = 0.1732 Time = 11.27
# [2019-05-12 16:14:43] Epoch = 159 Count = 300 Current_Loss = 0.2672 Time = 11.28
# [2019-05-12 16:14:55] Epoch = 159 Count = 320 Current_Loss = 0.1677 Time = 11.25
# [2019-05-12 16:15:06] Epoch = 159 Count = 340 Current_Loss = 0.1251 Time = 11.27
# [2019-05-12 16:15:17] Epoch = 159 Count = 360 Current_Loss = 0.0911 Time = 11.28
# [2019-05-12 16:15:29] Epoch = 159 Count = 380 Current_Loss = 0.1265 Time = 11.43
# [2019-05-12 16:15:40] Epoch = 159 Count = 400 Current_Loss = 0.1650 Time = 11.65
# [2019-05-12 16:15:51] Epoch = 159 Count = 420 Current_Loss = 0.1681 Time = 11.27
# Saving latest checkpoint
# Performing validation
#
# Average validation accuracy for epoch # 0159 = 0.873356
# Average per class validation accuracies for epoch # 0159:
# Animal = 0.995642
# Archway = 0.900000
# Bicyclist = 0.742075
# Bridge = 0.984315
# Building = 0.923718
# Car = 0.896883
# CartLuggagePram = 0.800116
# Child = 0.950951
# Column_Pole = 0.435553
# Fence = 0.820490
# LaneMkgsDriv = 0.389787
# LaneMkgsNonDriv = 1.000000
# Misc_Text = 0.722583
# MotorcycleScooter = 0.960753
# OtherMoving = 0.869751
# ParkingBlock = 0.850483
# Pedestrian = 0.667994
# Road = 0.947086
# RoadShoulder = 0.975740
# Sidewalk = 0.777366
# SignSymbol = 0.529818
# Sky = 0.950029
# SUVPickupTruck = 0.915734
# TrafficCone = 1.000000
# TrafficLight = 0.846691
# Train = 1.000000
# Tree = 0.807650
# Truck_Bus = 0.852946
# Tunnel = 1.000000
# VegetationMisc = 0.886753
# Void = 0.380858
# Wall = 0.751495
# Validation precision =  0.8954975679701146
# Validation recall =  0.8733560562133789
# Validation F1 score =  0.8776791969504482
# Validation IoU score =  0.5130677034604021
# [2019-05-12 16:16:12] Remaining training time : Training completed.

# %%
# %%writefile utils.py
from __future__ import print_function, division
import os,time,cv2, sys, math
import tensorflow as tf
import tensorflow.contrib.slim as slim
import numpy as np
import time, datetime
import os, random
from scipy.misc import imread
import ast
from sklearn.metrics import precision_score, \
    recall_score, confusion_matrix, classification_report, \
    accuracy_score, f1_score

from utils import tool

def prepare_data(dataset_dir):
    train_input=[]
    train_output=[]
    val_input=[]
    val_output=[]
    test_input=[]
    test_output=[]
    for file in os.listdir(dataset_dir + "/train"):
        cwd = os.getcwd()
        train_input.append(cwd + "/" + dataset_dir + "/train/" + file)
    for file in os.listdir(dataset_dir + "/train_labels"):
        cwd = os.getcwd()
        train_output.append(cwd + "/" + dataset_dir + "/train_labels/" + file)
    for file in os.listdir(dataset_dir + "/val"):
        cwd = os.getcwd()
        val_input.append(cwd + "/" + dataset_dir + "/val/" + file)
    for file in os.listdir(dataset_dir + "/val_labels"):
        cwd = os.getcwd()
        val_output.append(cwd + "/" + dataset_dir + "/val_labels/" + file)
    for file in os.listdir(dataset_dir + "/test"):
        cwd = os.getcwd()
        test_input.append(cwd + "/" + dataset_dir + "/test/" + file)
    for file in os.listdir(dataset_dir + "/test_labels"):
        cwd = os.getcwd()
        test_output.append(cwd + "/" + dataset_dir + "/test_labels/" + file)
    train_input.sort(),train_output.sort(), val_input.sort(), val_output.sort(), test_input.sort(), test_output.sort()
    return train_input,train_output, val_input, val_output, test_input, test_output

def load_image(path):
    return cv2.cvtColor(cv2.imread(path,-1), cv2.COLOR_BGR2RGB)


def filepath_to_name(name):
    file = os.path.basename(name)
    file = os.path.splitext(file)[0]
    return file


def LOG(X, f=None):
    stamp = datetime.datetime.now().strftime("[%Y-%m-%d %H:%M:%S]")
    if not f:
        print(stamp + " " + X)
    else:
        f.write(stamp + " " + X)



def total_params():
    total= 0
    for var in tf.trainable_variables():
        shape = var.get_shape()
        variable = 1
        for dim in shape:
            variable *= dim.value
        total += variable
    print("This model has %d trainable parameters"% (total))


def mean_image_subtraction(inputs, means=[123.68, 116.78, 103.94]):
    inputs=tf.to_float(inputs)
    num_channels = inputs.get_shape().as_list()[-1]
    if len(means) != num_channels:
      raise ValueError('len(means) must match the number of channels')
    channels = tf.split(axis=3, num_or_size_splits=num_channels, value=inputs)
    for i in range(num_channels):
        channels[i] -= means[i]
    return tf.concat(axis=3, values=channels)


def crop(image, label, crop_height, crop_width):
    if (image.shape[0] != label.shape[0]) or (image.shape[1] != label.shape[1]):
        raise Exception('Image and label must have the same dimensions!')
        
    if (crop_width <= image.shape[1]) and (crop_height <= image.shape[0]):
        x = random.randint(0, image.shape[1]-crop_width)
        y = random.randint(0, image.shape[0]-crop_height)
        
        if len(label.shape) == 3:
            return image[y:y+crop_height, x:x+crop_width, :], label[y:y+crop_height, x:x+crop_width, :]
        else:
            return image[y:y+crop_height, x:x+crop_width, :], label[y:y+crop_height, x:x+crop_width]
    else:
        raise Exception('Crop shape (%d, %d) exceeds image dimensions (%d, %d)!' % (crop_height, crop_width, image.shape[0], image.shape[1]))


def compute_global_accuracy(pred, label):
    total = len(label)
    count = 0.0
    for i in range(total):
        if pred[i] == label[i]:
            count = count + 1.0
    return float(count) / float(total)

# Compute the class-specific segmentation accuracy
def compute_class_accuracies(pred, label, num_classes):
    total = []
    for val in range(num_classes):
        total.append((label == val).sum())

    count = [0.0] * num_classes
    for i in range(len(label)):
        if pred[i] == label[i]:
            count[int(pred[i])] = count[int(pred[i])] + 1.0

    accuracies = []
    for i in range(len(total)):
        if total[i] == 0:
            accuracies.append(1.0)
        else:
            accuracies.append(count[i] / total[i])

    return accuracies


def compute_mean_iou(pred, label):

    unique_labels = np.unique(label)
    num_unique_labels = len(unique_labels);

    I = np.zeros(num_unique_labels)
    U = np.zeros(num_unique_labels)

    for index, val in enumerate(unique_labels):
        pred_i = pred == val
        label_i = label == val

        I[index] = float(np.sum(np.logical_and(label_i, pred_i)))
        U[index] = float(np.sum(np.logical_or(label_i, pred_i)))


    mean_iou = np.mean(I / U)
    return mean_iou


def evaluate_segmentation(pred, label, num_classes, score_averaging="weighted"):
    flat_pred = pred.flatten()
    flat_label = label.flatten()

    global_accuracy = compute_global_accuracy(flat_pred, flat_label)
    class_accuracies = compute_class_accuracies(flat_pred, flat_label, num_classes)

    prec = precision_score(flat_pred, flat_label, average=score_averaging)
    rec = recall_score(flat_pred, flat_label, average=score_averaging)
    f1 = f1_score(flat_pred, flat_label, average=score_averaging)

    iou = compute_mean_iou(flat_pred, flat_label)

    return global_accuracy, class_accuracies, prec, rec, f1, iou
# Out:
# Overwriting utils.py

# %%
cd ..
# Out:
# /content/Final_proj

# %%
cd utils
# Out:
# /content/Final_proj/utils

# %%
cd Final_proj
# Out:
# /content/Final_proj
